# %%
import requests
import pandas as pd
import numpy as np
import random

# %%
# !conda install -c conda-forge geopy --yes
# !pip install geopy

# %%
from geopy.geocoders import Nominatim

# %%
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML

# %%
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# %%
import folium  #plotting library

# %%
## Foursquare developer account

CLIENT_ID = 'id'
CLIENT_SECRET = 'secret'
VERSION = '20180604'
LIMIT = 30
print('My_Foursquare credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# My_Foursquare credentails:
# CLIENT_ID: id
# CLIENT_SECRET:secret

# %%
address = '18261 SW Fallatin Loop, Beaverton, OR'

# %%
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 45.4612831 -122.8656176

# %%
search_query = 'Italian'
radius = 50000   # this is in meters

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e2c6e571835dd001b08fc9c'},
#  'response': {'venues': [{'id': '4bafafa9f964a5208e173ce3',
#     'name': "Geraldi's Italian Eating Place",
#     'location': {'address': '10000 SW Canyon Rd',
#      'crossStreet': 'at SW Walker Rd',
#      'lat': 45.49321368310379,
#      'lng': -122.77936638368593,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.49321368310379,
#        'lng': -122.77936638368593}],
#      'distance': 7613,
#      'postalCode': '97225',
#      'cc': 'US',
#      'city': 'Portland',
#      'state': 'OR',
#      'country': 'United States',
#      'formattedAddress': ['10000 SW Canyon Rd (at SW Walker Rd)',
#       'Portland, OR 97225',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
# ...

# %%
venues = results['response']['venues']

dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...      556543
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...      330585
# 3                                                 []         NaN
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...         NaN
#
#                delivery.provider.icon.name  \
# 0  /delivery_provider_grubhub_20180129.png
# 1                                      NaN
# 2  /delivery_provider_grubhub_20180129.png
# 3                                      NaN
# 4                                      NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']

# %%
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
dataframe_filtered.head()
# Out:
#                              name  \
# 0  Geraldi's Italian Eating Place
# 1                   Italian Joint
# 2         Caro Amico Italian Cafe
# 3       Nico's Italian Restaurant
# 4           Pesaros Italian Grill
#
#                                           categories  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 3                                                 []
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
#
#              location.address location.cc location.city location.country  \
# 0          10000 SW Canyon Rd          US      Portland    United States
# 1      3145 SE Hawthorne Blvd          US      Portland    United States
# 2         3606 SW Barbur Blvd          US      Portland    United States
# 3             311 SW 17th Ave          US     Hillsboro    United States
# ...

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# %%
# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %%
dataframe_filtered
# Out:
#                                    name          categories  \
# 0        Geraldi's Italian Eating Place  Italian Restaurant
# 1                         Italian Joint  Italian Restaurant
# 2               Caro Amico Italian Cafe  Italian Restaurant
# 3             Nico's Italian Restaurant                None
# 4                 Pesaros Italian Grill  Italian Restaurant
# 5                  Sal's Famous Italian  Italian Restaurant
# 6             Italian Cafe & Gelato Bar                Café
# 7   Michael's Italian Beef & Sausage co       Hot Dog Joint
# 8            Gilda's Italian Restaurant  Italian Restaurant
# 9         Giovanni's Italian Restaurant  Italian Restaurant
# 10                         Italian Subs      Sandwich Place
# 11         Armando's Italian Restaurant  Italian Restaurant
# 12              Leonardo's Italian Cafe         Pizza Place
# 13               Abella Italian Kitchen  Italian Restaurant
# 14         Dream Italian Villas & Tours       Travel Agency
# ...

# %%
dataframe_filtered.name

venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Fallatin house

# add a red circle marker to represent Fallatin house
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Fallatin House',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venue_id = '4aff2bcaf964a5205f3522e3' # ID of Olive Garden
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4aff2bcaf964a5205f3522e3',
#  'name': 'Olive Garden',
#  'contact': {'phone': '5036440607',
#   'formattedPhone': '(503) 644-0607',
#   'twitter': 'olivegarden'},
#  'location': {'address': '11650 SW Canyon Rd',
#   'crossStreet': 'at Beaverton Town Square',
#   'lat': 45.48928976796522,
#   'lng': -122.79700752603684,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 45.48928976796522,
#     'lng': -122.79700752603684}],
#   'postalCode': '97005',
#   'cc': 'US',
#   'city': 'Beaverton',
#   'state': 'OR',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.4

# %%
result['response']['venue']['tips']['count']
# Out:
# 19

# %%
limit = 19 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                               text  \
# 0  Great food and the service it's great too. It's my favorite restaurant, definitely.
# 1  Very friendly and accommodating staff. Always quick to refill our soup, salad, and breadsticks.
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  2           0              5469382d498ebf7265e1adfb  Lule 🖤
# 1  4           0              4ff613e3e4b0fe7c2099ab3a  Andrew
#
#   user.lastName  user.gender   user.id
# 0  NaN          NaN           71992505
# 1  R            NaN           28444697

# %%
tips_filtered.dtypes
# Out:
# text              object
# agreeCount        int64
# disagreeCount     int64
# id                object
# user.firstName    object
# user.lastName     object
# user.gender       float64
# user.id           object
# dtype: object

# %%
user_id = '28444697' # user ID with most agree counts and complete profile

url = 'https://api.foursquare.com/v2/users/{}?client_id={}&client_secret={}&v={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION) # define URL

# send GET request
results = requests.get(url).json()
# user_data = results['response']['user']

# display features associated with user

results
# user_data.keys()
# Out:
# {'meta': {'code': 401,
#   'errorType': 'invalid_auth',
#   'errorDetail': 'Missing oauth_token. See https://developer.foursquare.com/docs/api/configuration/authentication for details.',
#   'requestId': '5e2c86e869babe001b2c93d8'},
#  'response': {}}

# %%
latitude = 45.48928976796522
longitude = -122.79700752603684
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=AJ3VPP1DWBF0J12LZGRXTTYPNXHAUS2L4PY5LCP4HQCAPDDN&client_secret=GSD53HFGA5LPASWKWMMJJZLRSUXJ3QA4PMXL51VEGNI4ARP5&ll=45.48928976796522,-122.79700752603684&v=20180604&radius=50000&limit=30'

# %%
#POPULAR SPOTS AROUND OLIVE GARDEN

results = requests.get(url).json()
'There are {} popular spots around Olive Garden.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 popular spots around Olive Garden.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4a91fcb6f964a520841c20e3',
#   'name': "Trader Joe's",
#   'location': {'address': '11753 SW Beaverton Hillsdale Hwy',
#    'crossStreet': 'at SW Lombard Ave',
#    'lat': 45.48806542108145,
#    'lng': -122.79824976019154,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 45.48806542108145,
#      'lng': -122.79824976019154}],
#    'distance': 167,
#    'postalCode': '97005',
#    'cc': 'US',
#    'city': 'Beaverton',
#    'state': 'OR',
#    'country': 'United States',
#    'formattedAddress': ['11753 SW Beaverton Hillsdale Hwy (at SW Lombard Ave)',
#     'Beaverton, OR 97005',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d118951735',
#     'name': 'Grocery Store',
#     'pluralName': 'Grocery Stores',
#     'shortName': 'Grocery Store',
# ...

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                        name             categories  \
# 0  Trader Joe's              Grocery Store
# 1  Tan Tan Cafe              Vietnamese Restaurant
# 2  Beaverton Farmers Market  Farmers Market
# 3  Uwajimaya                 Grocery Store
# 4  Du Kuh Bee                Korean Restaurant
# 5  Beaverton Sub Station     Sandwich Place
# 6  New Seasons Market        Grocery Store
# 7  Powell's Books            Bookstore
# 8  Ex Novo Brewing           Brewery
# 9  Nike Employee Store       Sporting Goods Shop
#
#                             address  cc       city        country  \
# 0  11753 SW Beaverton Hillsdale Hwy  US  Beaverton  United States
# 1  12675 SW Broadway St              US  Beaverton  United States
# 2  4900 SW Washington St             US  Beaverton  United States
# 3  10500 SW Beaverton Hillsdale Hwy  US  Beaverton  United States
# 4  12590 SW 1st St                   US  Beaverton  United States
# 5  12448 SW Broadway St              US  Beaverton  United States
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Olive Garden',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
##TRENDING VENUES

# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
# Out:
# {'meta': {'code': 200, 'requestId': '5e2c8c5dad1ab40020a653e9'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
    
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Olive Garden',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

        
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %%
# !pip install lxml

# %%
from bs4 import BeautifulSoup
